# %% [markdown]
# # <span style="color:red"> <strong> Popularity-based Recommender System  </strong>
#
# Popularity-based recommendation system offers generalized recommendations to every user, based on movie popularity and/or genre. The basic idea behind this system is that movies that are most popular and critically acclaimed will have a higher probability of being liked by the average audience. An example could be `IMDB Top 250`.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %% [markdown]
# ### Load Dataset

# %%
movie_df  = pd.read_csv("../data/movie.csv")
rating_df = pd.read_csv("../data/rating.csv")
movie_rating = movie_df.merge(rating_df, how="inner", on="movieId")
movie_rating["timestamp"] = pd.DatetimeIndex(movie_rating["timestamp"])
movie_rating["year"] = movie_rating["timestamp"].dt.year

# %%
movie_rating
# Out:
#           movieId                          title  \
# 0               1               Toy Story (1995)
# 1               1               Toy Story (1995)
# 2               1               Toy Story (1995)
# 3               1               Toy Story (1995)
# 4               1               Toy Story (1995)
# ...           ...                            ...
# 20000258   131254   Kein Bund für's Leben (2007)
# 20000259   131256  Feuer, Eis & Dosenbier (2002)
# 20000260   131258             The Pirates (2014)
# 20000261   131260            Rentun Ruusu (2001)
# 20000262   131262               Innocence (2014)
#
#                                                genres  userId  rating  \
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# 4         Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# ...                                               ...     ...     ...
# 20000258                                       Comedy   79570     4.0
# 20000259                                       Comedy   79570     4.0
# 20000260                                    Adventure   28906     2.5
# 20000261                           (no genres listed)   65409     3.0
# 20000262                     Adventure|Fantasy|Horror  133047     4.0
#
#                    timestamp  year
# 0        1999-12-11 13:36:47  1999
# 1        1997-03-13 17:50:52  1997
# 2        1996-06-05 13:37:51  1996
# 3        1999-11-25 02:44:47  1999
# 4        2009-01-02 01:13:41  2009
# ...                      ...   ...
# 20000258 2015-03-30 19:32:59  2015
# 20000259 2015-03-30 19:48:08  2015
# 20000260 2015-03-30 19:56:32  2015
# 20000261 2015-03-30 19:57:46  2015
# 20000262 2015-03-30 20:39:26  2015
#
# [20000263 rows x 7 columns]

# %% [markdown]
# ### Popularity-based Recommender
#
# In this part we are going to find the most popualr movies and recommend them to users. This can be useful for newcomers who know nothing about the movies.
#
# Hypothesis:
# * Historically popular movies should be recommended to new comers
#
# Data splitting strategy:
# * Data should be splitted according to `year` if we want to evaluate the effect of recommending highly rated movies to new comers
#
# Evaluation strategy:
# * Algorithm will be evaluated based on the overlapping rate between movies watched and movies recommended for each user

# %%
k = 50 #number of top movies that should be recommended
cutoff_year = 2015 #cut-off year for evaluation

most_voted = movie_rating[movie_rating["year"] < cutoff_year].groupby("movieId").mean()[["rating"]].sort_values(by="rating", ascending=False).reset_index().head(k)
most_voted = most_voted.merge(movie_df, how="inner", on="movieId")
most_voted = most_voted.rename(columns={"rating" : "Avg_rating"})
most_voted
# Out:
# /var/folders/cf/3kbbttcn1g35qhk6ldvlg1lh0000gn/T/ipykernel_52759/3178553431.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   most_voted = movie_rating[movie_rating["year"] < cutoff_year].groupby("movieId").mean()[["rating"]].sort_values(by="rating", ascending=False).reset_index().head(k)
#     movieId  Avg_rating                                              title  \
# 0    103143         5.0                           Donos de Portugal (2012)
# 1    116261         5.0                           Wuthering Heights (2009)
# 2    105187         5.0                          Linotype: The Film (2012)
# 3    105135         5.0                                    Pit, The (1981)
# 4    109931         5.0                      Repentance (Monanieba) (1984)
# 5    116387         5.0                                 Muddy River (1981)
# 6    101188         5.0                                Central Park (1991)
# 7    113860         5.0                        Codes of Gender, The (2010)
# 8     93707         5.0             Prom Queen: The Marc Hall Story (2004)
# 9    100743         5.0                  Eye In The Sky (Gun chung) (2007)
# 10    93967         5.0  Keeping the Promise (Sign of the Beaver, The) ...
# 11   114254         5.0                                        1971 (2014)
# 12   107434         5.0                       Diplomatic Immunity (2009– )
# 13   113244         5.0                                 When I Walk (2013)
# 14    72235         5.0     Between the Devil and the Deep Blue Sea (1995)
# 15   101855         5.0                              Shepard & Dark (2012)
# 16   105191         5.0                                Rocaterrania (2009)
# 17   109571         5.0                  Into the Middle of Nowhere (2010)
# 18   104317         5.0    Flight of the Conchords: A Texan Odyssey (2006)
# 19   113790         5.0       Peace, Propaganda & the Promised Land (2004)
# 20   116722         5.0                        Stromberg - Der Film (2014)
# 21   105841         5.0                                      B-Side (2013)
# 22   111797         5.0                       This Thing With Sarah (2013)
# 23    52365         5.0                              Palais royal ! (2005)
# 24   107643         5.0          Here Without Me (Inja bedoone man) (2011)
# 25   100521         5.0                    Who Killed Vincent Chin? (1987)
# 26   105529         5.0                           Stealing a Nation (2004)
# 27    92956         5.0                            Little Criminals (1995)
# 28   113793         5.0  Reel Bad Arabs: How Hollywood Vilifies a Peopl...
# 29   105526         5.0     Year Zero: The Silent Death of Cambodia (1979)
# 30    92783         5.0                             Latin Music USA (2009)
# 31    81117         5.0                             Moth, The (Cma) (1980)
# 32    51167         5.0       My Father and My Son (Babam ve oglum) (2005)
# 33    32230         5.0            Snow Queen, The (Lumikuningatar) (1986)
# 34   118896         5.0                                       Mommy (2014)
# 35    86055         5.0        Foster Brothers, The (Süt kardesler) (1976)
# 36    27914         5.0  Hijacking Catastrophe: 9/11, Fear & the Sellin...
# 37    94972         5.0                 Best of Ernie and Bert, The (1988)
# 38    94737         5.0                       Boys Diving, Honolulu (1901)
# 39   118392         5.0             Street Fighter: Assassin's Fist (2014)
# 40   118610         5.0                               Rock the Boat (1944)
# 41   112790         5.0                    Going Down in LA-LA Land (2011)
# 42   110419         5.0                Palestine Is Still the Issue (2003)
# 43    94949         5.0                               Boy Meets Boy (2008)
# 44    40404         5.0                                Al otro lado (2004)
# 45   114193         5.0  Hollywood and The Pentagon: A Dangerous Liaiso...
# 46    95977         5.0                                 Junior Prom (1946)
# 47    95776         5.0                                    Bob Funk (2009)
# 48   102882         5.0                                 Dream Demon (1988)
# 49    95517         5.0                  Barchester Chronicles, The (1982)
#
#                                          genres
# 0                                   Documentary
# 1                                         Drama
# 2                                   Documentary
# 3                                        Horror
# 4                                         Drama
# 5                                         Drama
# 6                                   Documentary
# 7                                   Documentary
# 8                                  Comedy|Drama
# 9                                Crime|Thriller
# 10                               Children|Drama
# 11                                  Documentary
# 12                                       Comedy
# 13                                  Documentary
# 14                                        Drama
# 15                                  Documentary
# 16                          Documentary|Fantasy
# 17  Adventure|Children|Comedy|Documentary|Drama
# 18                                       Comedy
# 19                                  Documentary
# 20                                       Comedy
# 21                               Comedy|Romance
# 22                         Comedy|Drama|Romance
# 23                                       Comedy
# 24              Drama|Film-Noir|Mystery|Romance
# 25                            Crime|Documentary
# 26                                  Documentary
# 27                                  Crime|Drama
# 28                                  Documentary
# 29                                  Documentary
# 30                          Documentary|Musical
# 31                                        Drama
# 32                                        Drama
# 33                             Children|Fantasy
# 34                                        Drama
# 35                                       Comedy
# 36                                  Documentary
# 37                                     Children
# 38                                  Documentary
# 39              Action|Adventure|Drama|Thriller
# 40                                    Animation
# 41                         Comedy|Drama|Romance
# 42                                  Documentary
# 43                                      Romance
# 44                                        Drama
# 45                                  Documentary
# 46                                  Documentary
# 47                               Comedy|Romance
# 48                                       Horror
# 49                                        Drama

# %% [markdown]
# As is shown in the table, the top 50 rated movies will be recommended to each user in year 2015.
#
# ### Evaluation with Precision @k and Recall @k
#
# Now let's evaluate the performance of popularity-based recommender!
#
#
# `Recall` is the percentage of relevant items selected out of all the relevant items in the repository:
#
# - <span style="color:yellow"> Recall@k = Relevant Items Recommended in top k / Relevant Items
#
# `Precision` is the percentage of relevant items out of those items selected by the query
#
# - <span style="color:yellow"> Precision@k = Relevant Items Recommended in top k / k items recommended

# %%
userIds = list(movie_rating[movie_rating["year"] >= cutoff_year]["userId"].unique())

relevant_items = movie_rating[movie_rating["year"] >= cutoff_year][["userId", "movieId"]]#ground-truth movies
recommended_items = most_voted[["movieId"]]#predicted movies

# %%
def precision_at_k_score(relevant, topk):
    num = 0
    for item in relevant:
        if item in topk:
            num += 1
    return num / k

def recall_at_k_score(relevant, topk):
    num = 0
    for item in relevant:
        if item in topk:
            num += 1
    return num / len(relevant)

    
#calculate the average precision@k for all the users
sum_precision = 0
sum_recall = 0
for user in userIds:
    relevant = relevant_items[relevant_items["userId"]==user]["movieId"]
    recommendation = recommended_items["movieId"]
    sum_precision += precision_at_k_score(relevant, recommendation)
    sum_recall += recall_at_k_score(relevant, recommendation)

print("Average Precision@k :{}".format(sum_precision/len(userIds)))
print("Average Recall@k :{}".format(sum_recall/len(userIds)))
# Out:
# Average Precision@k :0.014219830899308497
# Average Recall@k :0.0073768100982868085

# %% [markdown]
# ### Conclusion
#
# Our results show that the `Precision@k` of the popularity-based recommender is 1.4%, which means among top 50 recommended movies, only 2.8 movies were watched by users on average. The `Recall@k` is 0.7%, which means among all the movies each user watched, only 0.7 movies are recommended by the algorithm on average.
